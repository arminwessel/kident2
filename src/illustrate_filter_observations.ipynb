# %%
from da_test_suite_functions import *
from exp_data_handler import *
from robot import RobotDescription
import matplotlib.pyplot as plt

# %%
obs_files = {20: r'observation_files/obs_single_marker_2023-11-01-11-12-21_20240109-060457.p',
             21: r'observation_files/observations_simulated_20240109_081340.p'}


# set filter threshold
mal_threshold = 20

# %%
    ##########################################################################
    # 2) Import and filter observations to be used
    ##########################################################################
    # import selected observations
    df_observations = pd.read_pickle(obs_files[20])
    num_obs_unfiltered = df_observations.shape[0]  # number of records before filtering

    # filter
    df_obs_filt = reject_outliers_by_mahalanobis_dist(df_observations, mal_threshold)
    num_obs_filtered = df_obs_filt.shape[0]  # number of records before filtering
    print(f"{num_obs_filtered} /  {num_obs_unfiltered} observations after filtering")
# Out:
# 802 /  1013 observations after filtering

# %%
df_obs_filt
# Out:
#      marker_id                                                mat      t  \
# 0            2  [[-0.6512959642736411, 0.10584934278182084, 0....   32.2
# 1            2  [[-0.6219646738877594, 0.13994134799481425, 0....   32.4
# 2            2  [[-0.586827628389369, 0.17561501094231632, 0.7...   32.6
# 726          2  [[-0.5722888661928018, 0.4374456413270155, 0.6...  187.2
# 727          2  [[-0.5746882022193125, 0.43577988279418484, 0....  187.4
# ..         ...                                                ...    ...
# 867          5  [[-0.6154103833902165, -0.09248950478344467, 0...  232.4
# 868          5  [[-0.6120128755975259, -0.09335599069504422, 0...  232.6
# 869          5  [[-0.6046362436865251, -0.09845332874258306, 0...  232.8
# 870          5  [[-0.6023602801838269, -0.1035581780019883, 0....  233.0
# 871          5  [[-0.5988711948541605, -0.10475323287982322, 0...  233.2
#
#                                                      q  interp_dist  \
# 0    [0.06164954886680629, 0.18593552125506285, 0.0...          0.0
# 1    [0.0811436023569394, 0.2441870706374587, 0.040...          0.0
# 2    [0.10140595695741439, 0.3049633047415341, 0.05...          0.0
# 726  [0.5999910952101839, -1.199891364993289, 0.200...          0.0
# 727  [0.5999902897513678, -1.1998913402821696, 0.20...          0.0
# ..                                                 ...          ...
# 867  [0.39996869621692355, -0.8818552995503248, 0.1...          0.0
# 868  [0.3999687091004498, -0.9021640124527517, 0.19...          0.0
# 869  [0.3999682466966368, -0.9225787352686821, 0.19...          0.0
# 870  [0.3999696963809045, -0.9426820184991263, 0.19...          0.0
# 871  [0.3999728507742457, -0.9625589754052788, 0.19...          0.0
#
#      mahal_dist
# 0     19.650211
# 1     10.539910
# 2     16.276817
# 726    4.542986
# 727    3.673538
# ..          ...
# 867    8.728489
# 868    4.952995
# 869    5.517825
# 870    8.683609
# 871    8.036240
#
# [802 rows x 6 columns]

# %%
from acin_colors import acin_colors

# %%
s=0.5
fig, axs = plt.subplots(1,3, figsize=(s*15,s*4.5))

df_plot_unfilt = df_observations[df_observations['marker_id']==2]
df_plot_filt = df_obs_filt[df_obs_filt['marker_id']==2]

locations_filt = np.array(get_marker_locations(df_plot_filt))[:,3:6]*1000
#print(locations_filt)

locations_unfilt = np.array(get_marker_locations(df_plot_unfilt))[:,3:6]*1000
print(locations_unfilt)


axs[0].scatter(locations_unfilt[:,0], locations_unfilt[:,1], c=acin_colors['red'], edgecolors='black', label='rejected') # x, y
axs[1].scatter(locations_unfilt[:,2], locations_unfilt[:,0], c=acin_colors['red'], edgecolors='black') # z, x
axs[2].scatter(locations_unfilt[:,1], locations_unfilt[:,2], c=acin_colors['red'], edgecolors='black') # y, z

axs[0].scatter(locations_filt[:,0], locations_filt[:,1], c=acin_colors['blue'], edgecolors='black', label='passed') # x, y
axs[1].scatter(locations_filt[:,2], locations_filt[:,0], c=acin_colors['blue'], edgecolors='black') # z, x
axs[2].scatter(locations_filt[:,1], locations_filt[:,2], c=acin_colors['blue'], edgecolors='black') # y, z
    
axs[0].set_xlabel('x [mm]')
axs[0].set_ylabel('y [mm]')
axs[1].set_xlabel('z [mm]')
axs[1].set_ylabel('x [mm]')
axs[2].set_xlabel('y [mm]')
axs[2].set_ylabel('z [mm]')
fig.tight_layout()

axs[0].legend()
axs[1].set_xticks([1352, 1356, 1360])

plt.savefig('illustrate_filter_obs.pdf', format='pdf', bbox_inches='tight')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# [[1.47680803e+03 8.71468936e-01 1.35236738e+03]
#  [1.47708410e+03 9.81373477e-01 1.35203781e+03]
#  [1.47658069e+03 8.39143359e-01 1.35218687e+03]
#  [1.47752095e+03 8.74816504e-01 1.35229698e+03]
#  [1.47558328e+03 5.61504710e-01 1.35211033e+03]
#  [1.54398887e+03 3.70616454e+00 1.36027452e+03]
#  [1.47695545e+03 1.39073507e+00 1.35217879e+03]
#  [1.47786087e+03 1.58150167e+00 1.35243126e+03]
#  [1.47738252e+03 1.21501148e+00 1.35233733e+03]
#  [1.47498379e+03 1.42975315e+00 1.35211195e+03]
#  [1.47687764e+03 1.57839323e+00 1.35244610e+03]
#  [1.47731888e+03 1.69725939e+00 1.35260359e+03]
#  [1.47781136e+03 1.42164729e+00 1.35255499e+03]
#  [1.47518473e+03 1.51910868e+00 1.35199881e+03]
#  [1.47804995e+03 1.54394424e+00 1.35244280e+03]
#  [1.47282914e+03 1.44703918e+00 1.35188104e+03]
#  [1.47497853e+03 1.39760748e+00 1.35191933e+03]
