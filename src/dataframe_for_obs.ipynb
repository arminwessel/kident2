# %%
import pandas as pd
import numpy as np
import pickle
import utils

# %%
# df = utils.open_df_from_pickle('obs_single_marker_2023-11-01-11-12-21_20240106-183157.p')
df = pd.read_pickle('obs_single_marker_2023-11-01-11-12-21_20240106-185908.p')
print(df)
# Out:
#       marker_id                                                mat      t  \
# 0             2  [[-0.6512959642736411, 0.10584934278182084, 0....   32.2
# 1             2  [[-0.6219646738877594, 0.13994134799481425, 0....   32.4
# 2             2  [[-0.586827628389369, 0.17561501094231632, 0.7...   32.6
# 3             1  [[-0.8596319172505427, 0.20944688727684876, 0....   32.8
# 4             2  [[-0.5520186946789184, 0.20810937543488303, 0....   32.8
# ...         ...                                                ...    ...
# 1008          4  [[-0.8548456123773195, -0.11758664681680067, 0...  267.6
# 1009          4  [[-0.8573968887430287, -0.11705664318983587, 0...  267.8
# 1010          4  [[-0.857574609538824, -0.1154735421995034, 0.5...  268.0
# 1011          4  [[-0.8589465995702666, -0.10754760359722929, 0...  268.2
# 1012          4  [[-0.8642795087414036, -0.09588814454161206, 0...  268.4
#
#                                                       q  interp_dist
# ...

# %%
observations_file = open('obs_single_marker_2023-11-01-11-12-21_20240106-183157.p', 'rb')
df_pickle = pickle.load(observations_file)
observations_file.close()
print(df_pickle)
# Out:
# [{'marker_id': 2, 'mat': array([[-0.65129596,  0.10584934,  0.75140501,  1.36118988],
#        [ 0.07335671,  0.99436804, -0.07649174, -0.14977664],
#        [-0.75526973,  0.00530184, -0.65539265,  0.05316793],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 't': 32.2, 'q': array([ 6.16495489e-02,  1.85935521e-01,  3.11221361e-02,  1.83329306e-01,
#        -4.39026464e-06,  1.09010803e-01,  1.49311960e-02]), 'interp_dist': 0.0}, {'marker_id': 2, 'mat': array([[-0.62196467,  0.13994135,  0.77043907,  1.31780723],
#        [ 0.09471675,  0.9901218 , -0.10338067, -0.19417861],
#        [-0.77729575,  0.00867436, -0.62907557,  0.10408574],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 't': 32.4, 'q': array([8.11436024e-02, 2.44187071e-01, 4.07439551e-02, 2.41083115e-01,
#        7.66227499e-05, 1.44968791e-01, 2.04622310e-02]), 'interp_dist': 0.0}, {'marker_id': 2, 'mat': array([[-0.58682763,  0.17561501,  0.7904383 ,  1.26792846],
# ...

# %%
df = pd.DataFrame(df_pickle)

# %%
print(df)
# Out:
#       marker_id                                                mat      t  \
# 0             2  [[-0.6512959642736411, 0.10584934278182084, 0....   32.2
# 1             2  [[-0.6219646738877594, 0.13994134799481425, 0....   32.4
# 2             2  [[-0.586827628389369, 0.17561501094231632, 0.7...   32.6
# 3             1  [[-0.8596319172505427, 0.20944688727684876, 0....   32.8
# 4             2  [[-0.5520186946789184, 0.20810937543488303, 0....   32.8
# ...         ...                                                ...    ...
# 1008          4  [[-0.8548456123773195, -0.11758664681680067, 0...  267.6
# 1009          4  [[-0.8573968887430287, -0.11705664318983587, 0...  267.8
# 1010          4  [[-0.857574609538824, -0.1154735421995034, 0.5...  268.0
# 1011          4  [[-0.8589465995702666, -0.10754760359722929, 0...  268.2
# 1012          4  [[-0.8642795087414036, -0.09588814454161206, 0...  268.4
#
#                                                       q  interp_dist
# ...

# %%
list_dicts = df.to_dict('records')

# %%
print(list_dicts)
# Out:
# [{'marker_id': 2, 'mat': array([[-0.65129596,  0.10584934,  0.75140501,  1.36118988],
#        [ 0.07335671,  0.99436804, -0.07649174, -0.14977664],
#        [-0.75526973,  0.00530184, -0.65539265,  0.05316793],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 't': 32.2, 'q': array([ 6.16495489e-02,  1.85935521e-01,  3.11221361e-02,  1.83329306e-01,
#        -4.39026464e-06,  1.09010803e-01,  1.49311960e-02]), 'interp_dist': 0.0}, {'marker_id': 2, 'mat': array([[-0.62196467,  0.13994135,  0.77043907,  1.31780723],
#        [ 0.09471675,  0.9901218 , -0.10338067, -0.19417861],
#        [-0.77729575,  0.00867436, -0.62907557,  0.10408574],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 't': 32.4, 'q': array([8.11436024e-02, 2.44187071e-01, 4.07439551e-02, 2.41083115e-01,
#        7.66227499e-05, 1.44968791e-01, 2.04622310e-02]), 'interp_dist': 0.0}, {'marker_id': 2, 'mat': array([[-0.58682763,  0.17561501,  0.7904383 ,  1.26792846],
# ...
